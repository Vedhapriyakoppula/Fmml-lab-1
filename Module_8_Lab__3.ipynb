# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedhapriyakoppula/Fmml-lab-1/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-02 03:34:30--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   302MB/s    in 0.2s
#
# 2024-04-02 03:34:34 (302 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22439  1607.01369v3  Given a graph in which a few vertices are deem...  stat
# 1128   1711.11059v1  We propose stochastic, non-parametric activati...  stat
# 7251   1711.04894v1  We propose a new Integral Probability Metric (...    cs
# 2279   1801.00085v1  Learning probability distributions on the weig...  stat
# 12952  1604.01785v1  We formalize the idea of probability distribut...  stat
# ...             ...                                                ...   ...
# 39683  1701.07164v1  Painting is an art form that has long function...    cs
# 22463  1608.02280v1  Recently, a general method for analyzing the s...  stat
# 18676   1108.5002v2  In a knowledge discovery process, interpretati...    cs
# 3796   1703.07915v1  Machine learning techniques are being increasi...  stat
# 6257   1610.05672v2  Computing partition functions, the normalizing...  stat
#
#                                                    title  year  \
# 22439  On the Consistency of the Likelihood Maximizat...  2016
# 1128   Gaussian Process Neurons Learn Stochastic Acti...  2017
# 7251                                         Sobolev GAN  2017
# 2279   Learning Structural Weight Uncertainty for Seq...  2017
# 12952                                   Safe Probability  2016
# ...                                                  ...   ...
# 39683  Understanding the Historic Emergence of Divers...  2017
# 22463  Statistical Guarantees for Estimating the Cent...  2016
# 18676  Verbal Characterization of Probabilistic Clust...  2011
# 3796   Perspective: Energy Landscapes for Machine Lea...  2017
# 6257   Markov Chain Truncation for Doubly-Intractable...  2016
#
#                                                 keywords
# 22439  [interesting, nomination, remaining, nominatio...
# 1128   [stochastic, parametric, activation, functions...
# 7251   [probability, distributions, discrepancy, dist...
# 2279   [probability, distributions, beneficial, appli...
# 12952  [formalize, probability, distributions, predic...
# ...                                                  ...
# 39683  [functioned, communication, expression, unders...
# 22463  [analyzing, statistical, algorithm, developed,...
# 18676  [knowledge, discovery, interpretation, evaluat...
# 3796   [techniques, increasingly, prediction, functio...
# 6257   [computing, partition, functions, normalizing,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22439    [interesting, nomination, remaining, nominatio...
# 1128     [stochastic, parametric, activation, functions...
# 7251     [probability, distributions, discrepancy, dist...
# 2279     [probability, distributions, beneficial, appli...
# 12952    [formalize, probability, distributions, predic...
#                                ...
# 22260    [blitzkriging, inference, processes, applicabl...
# 18543    [reasoning, resolving, conflicts, acceptable, ...
# 11369    [neuroprosthetic, interfaces, algorithm, movem...
# 39502    [everywhere, particular, universal, arbitrary,...
# 30661    [universal, adversarial, universal, transforma...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8851 words.
# Out of those 4580 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ea347bc5-7370-449d-a32e-e4f6d79d1709" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea347bc5-7370-449d-a32e-e4f6d79d1709")) {                    Plotly.newPlot(                        "ea347bc5-7370-449d-a32e-e4f6d79d1709",                        [{"x":["consistent","approaches","including","empirical","theoretical","nomination","likelihood","incorporate","additionally","stochastic","restricted","consistency","effectiveness","remaining","introduce","interesting","concentration","classifier","estimation","maximization","parameters","asymptotically","performance","inference","preliminary","efficiently","structures","available","learnable","structure","comparable","activation","classification","experiments","complexity","confidence","convolutional","posterior","probabilistic","variational","uncertainties","controlled","predictions","recurrent","evaluation","favorably","parametric","graphical","overfitting","regularized","regression","processing","intrinsically","functions","deterministic","individual","conventional","distribution","efficiency","alongside","processes","generation","dimensions","probability","smoothness","laplacian","generative","distributions","intrinsic","extension","adversarial","dimensional","regularization","conditional","supervised","competitive","discrepancy","conditioning","cumulative","statistics","coordinate","investigate","framework","applications","reinforcement","beneficial","efficient","information","structural","uncertainty","sequential","synthetic","superiority","employing","contextual","independent","knowledge","automatically","restricting","imprecise","perspective","calibration","strongest","formalize","unbiasedness","resulting","foundational","variables","providing","prevalence","properties","neutrosophic","indeterminacy","attributes","contradiction","dialectical","construct","numerical","algebraic","components","antithesis","classical","afterwards","synthesis","refinement","multiplication","particular","operators","splitting","referring","noisiness","bipartite","objective","assigning","evaluated","baselines","condition","initialization","availability","retrospective","parameter","electronic","conditions","prediction","effective","outperforms","classifiers","emphasize","assessing","differences","diversity","examining","observable","representation","developing","different","constructing","interactions","prodromal","significantly","simulation","differentiating","cognitive","minimizes","participants","outperform","cognition","challenging","distinguish","significant","improving","substantial","conversational","alzheimers","specifically","impairment","transcribed","conversation","promising","especially","diagnosis","transcripts","progression","maximizes","alleviate","depression","simultaneously","considerable","neighborhood","precision","estimates","establish","illustrated","deteriorates","convergence","treatment","universally","possesses","eventually","selection"],"y":[82,423,250,151,169,1,60,73,63,130,52,46,193,20,318,70,6,158,205,32,223,9,826,225,48,166,118,300,12,336,94,28,526,600,239,36,380,58,159,52,12,37,90,150,232,22,46,65,27,32,126,314,7,239,35,126,99,229,144,7,91,161,42,177,15,21,120,138,35,80,89,172,85,98,194,97,13,12,18,49,28,151,529,420,122,25,402,721,76,76,68,123,32,25,49,139,363,171,5,7,86,10,4,8,1,148,2,120,98,3,215,4,3,64,5,2,84,77,21,104,2,92,11,40,26,6,303,42,7,12,1,8,165,12,141,66,56,23,32,0,122,12,129,247,254,255,117,13,17,37,44,11,17,338,70,748,37,71,1,257,78,4,62,15,17,105,14,266,28,247,93,42,12,9,161,3,2,15,101,107,50,3,9,14,24,3,117,38,20,76,84,47,26,1,109,28,3,4,8,157],"type":"bar"},{"x":["consistent","approaches","including","empirical","theoretical","nomination"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4580,), (4580, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7875

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.6483516483516483);'>Extraction</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>Color</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>Similarity</span> <br/><br/><span style=''>Many</span> <span style=''>User</span> <span style='background-color:rgba(0, 255, 0, 0.6428571428571428);'>interactive</span> <span style=''>systems</span> <span style=''>are</span> <span style=''>proposed</span> <span style=''>all</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>trying</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>as</span> <span style=''>a</span> <span style=''>user</span> <span style=''>friendly</span> <span style=''>and</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>proposed</span> <span style=''>but</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>systems</span> <span style=''>not</span> <span style=''>reached</span> <span style=''>to</span> <span style=''>the</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>specifications</span> <span style=''>like</span> <span style=''>user</span> <span style=''>friendly</span> <span style=''>systems</span> <span style=''>with</span> <span style=''>user</span> <span style=''>interest</span> <span style=''>all</span> <span style=''>proposed</span> <span style=''>method</span> <span style='background-color:rgba(0, 255, 0, 0.375886524822695);'>implemented</span> <span style=''>basic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>some</span> <span style=''>are</span> <span style=''>improved</span> <span style=''>methods</span> <span style=''>also</span> <span style=''>propose</span> <span style=''>but</span> <span style=''>not</span> <span style=''>reaching</span> <span style=''>to</span> <span style=''>the</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>specifications</span> <span style=''>In</span> <span style=''>this</span> <span style=''>proposed</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concentrated</span> <span style=''>on</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6496350364963503);'>retrieval</span> <span style=''>system</span> <span style=''>with</span> <span style=''>in</span> <span style=''>early</span> <span style=''>days</span> <span style=''>many</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.6428571428571428);'>interactive</span> <span style=''>systems</span> <span style='background-color:rgba(0, 255, 0, 0.3505154639175258);'>performed</span> <span style=''>with</span> <span style=''>basic</span> <span style=''>concepts</span> <span style=''>but</span> <span style=''>such</span> <span style=''>systems</span> <span style=''>are</span> <span style=''>not</span> <span style=''>reaching</span> <span style=''>to</span> <span style=''>the</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>specifications</span> <span style=''>and</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3888888888888889);'>attracted</span> <span style=''>to</span> <span style=''>the</span> <span style=''>user</span> <span style=''>so</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>of</span> <span style=''>research</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>with</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>specifications</span> <span style=''>recent</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Detecting</span> <span style=''>early</span> <span style=''>signs</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depressive</span> <span style=''>and</span> <span style=''>manic</span> <span style=''>episodes</span> <span style=''>in</span> <span style=''>patients</span> <span style=''>with</span> <span style=''>bipolar</span> <span style=''>disorder</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>signature</span> <span style=''>based</span> <span style=''>model</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>major</span> <span style=''>mood</span> <span style=''>episodes</span> <span style=''>and</span> <span style=''>subsyndromal</span> <span style=''>mood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instability</span> <span style=''>cause</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disability</span> <span style=''>in</span> <span style=''>patients</span> <span style=''>with</span> <span style=''>bipolar</span> <span style=''>disorder</span> <span style=''>Early</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>of</span> <span style=''>mood</span> <span style=''>episodes</span> <span style=''>enabling</span> <span style=''>timely</span> <span style=''>mood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stabilisation</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>clinical</span> <span style=''>goal</span> <span style=''>Recent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technological</span> <span style=''>advances</span> <span style=''>allow</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prospective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reporting</span> <span style=''>of</span> <span style=''>mood</span> <span style=''>in</span> <span style=''>real</span> <span style=''>time</span> <span style=''>enabling</span> <span style=''>more</span> <span style=''>accurate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>data</span> <span style=''>capture</span> <span style=''>The</span> <span style=''>complex</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>these</span> <span style=''>data</span> <span style=''>streams</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>of</span> <span style=''>deriving</span> <span style=''>meaning</span> <span style=''>from</span> <span style=''>missing</span> <span style=''>data</span> <span style=''>mean</span> <span style=''>pose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>analytic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>signature</span> <span style=''>method</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>has</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>capture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>complex</span> <span style=''>ordered</span> <span style=''>tim ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>Online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Randomized</span> <span style=''>Skeleton</span> <span style=''>Sets</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>fast</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>reliably</span> <span style=''>recovers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>shaped</span> <span style=''>data</span> <span style=''>clusters</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>throughout</span> <span style=''>data</span> <span style=''>streams</span> <span style=''>Unlike</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style=''>based</span> <span style=''>on</span> <span style=''>k</span> <span style=''>means</span> <span style=''>or</span> <span style=''>k</span> <span style=''>medoid</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>make</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3913043478260869);'>restrictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumptions</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>in</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.6788321167883211);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>such</span> <span style=''>as</span> <span style=''>DBScan</span> <span style=''>or</span> <span style=''>DenStream</span> <span style=''>it</span> <span style=''>gives</span> <span style=''>provable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3179190751445087);'>guarantees</span> <span style=''>To</span> <span style=''>achieve</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.39130434782608703);'>represent</span> <span style=''>each</span> <span style=''>cluster</span> <span style=''>by</span> <span style=''>a</span> <span style=''>skeleton</span> <span style=''>set</span> <span style=''>which</span> <span style=''>is</span> <span style=''>updated</span> <span style='background-color:rgba(0, 255, 0, 0.6153846153846154);'>continuously</span> <span style=''>as</span> <span style=''>new</span> <span style=''>data</span> <span style=''>is</span> <span style=''>seen</span> <span style=''>A</span> <span style=''>skeleton</span> <span style=''>set</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>weighted</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>the</span> <span style=''>data</span> <span style=''>where</span> <span style=''>weights</span> <span style=''>encode</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.6296296296296297);'>densities</span> <span style=''>The</span> <span style=''>size</span> <span style=''>of</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>Multi</span> <span style=''>Plate</span> <span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Throughput</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Screening</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compounds</span> <br/><br/><span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>throughput</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>screening</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compounds</span> <span style=''>(chemicals)</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essential</span> <span style=''>part</span> <span style=''>of</span> <span style=''>drug</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery</span> <span style=''>7</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>involving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>thousands</span> <span style=''>to</span> <span style=''>millions</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compounds</span> <span style=''>with</span> <span style=''>the</span> <span style=''>purpose</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>hits</span> <span style=''>Most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>tools</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>the</span> <span style=''>industry</span> <span style=''>standard</span> <span style=''>B</span> <span style=''>score</span> <span style=''>method</span> <span style=''>work</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>compound</span> <span style=''>plates</span> <span style=''>and</span> <span style=''>do</span> <span style=''>not</span> <span style=''>exploit</span> <span style=''>cross</span> <span style=''>plate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>strength</span> <span style=''>among</span> <span style=''>plates</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>throughput</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>screening</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compounds</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>modeling</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>identify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>hits</span> <span style=''>from</span> <span style=''>multiple</span> <span style=''>plates</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>sharing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>strength</span> <span style=''>among</span> <span style=''>plates</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>more</span> <span style=''>robus ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06427556818181818)
# 	knowledge (0.12890625)
# 	architecture (0.09197443181818182)
# 	experimental (0.1377840909090909)
# 	information (0.2560369318181818)
# 	processing (0.11150568181818182)
# 	detection (0.12322443181818182)
# 	recognition (0.12642045454545456)
# 	different (0.265625)
# 	convolutional (0.13494318181818182)
#
# Some Statistics words are:
# 	theoretical (0.1466733870967742)
# 	statistical (0.14415322580645162)
# 	estimation (0.16280241935483872)
# 	stochastic (0.1381048387096774)
# 	variables (0.13608870967741934)
# 	dimensional (0.18094758064516128)
# 	inference (0.20211693548387097)
# 	distribution (0.20514112903225806)
# 	regression (0.17036290322580644)
# 	algorithm (0.41985887096774194)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="59360acb-3af6-40cf-b4ec-09a33e415a12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59360acb-3af6-40cf-b4ec-09a33e415a12")) {                    Plotly.newPlot(                        "59360acb-3af6-40cf-b4ec-09a33e415a12",                        [{"x":["consistent","approaches","including","empirical","theoretical","nomination","likelihood","incorporate","additionally","stochastic","restricted","consistency","effectiveness","remaining","introduce","interesting","concentration","classifier","estimation","maximization","parameters","asymptotically","performance","inference","preliminary","efficiently","structures","available","learnable","structure","comparable","activation","classification","experiments","complexity","confidence","convolutional","posterior","probabilistic","variational","uncertainties","controlled","predictions","recurrent","evaluation","favorably","parametric","graphical","overfitting","regularized","regression","processing","intrinsically","functions","deterministic","individual","conventional","distribution","efficiency","alongside","processes","generation","dimensions","probability","smoothness","laplacian","generative","distributions","intrinsic","extension","adversarial","dimensional","regularization","conditional","supervised","competitive","discrepancy","conditioning","cumulative","statistics","coordinate","investigate","framework","applications","reinforcement","beneficial","efficient","information","structural","uncertainty","sequential","synthetic","superiority","employing","contextual","independent","knowledge","automatically","restricting","imprecise","perspective","calibration","strongest","formalize","unbiasedness","resulting","foundational","variables","providing","prevalence","properties","neutrosophic","indeterminacy","attributes","contradiction","dialectical","construct","numerical","algebraic","components","antithesis","classical","afterwards","synthesis","refinement","multiplication","particular","operators","splitting","referring","noisiness","bipartite","objective","assigning","evaluated","baselines","condition","initialization","availability","retrospective","parameter","electronic","conditions","prediction","effective","outperforms","classifiers","emphasize","assessing","differences","diversity","examining","observable","representation","developing","different","constructing","interactions","prodromal","significantly","simulation","differentiating","cognitive","minimizes","participants","outperform","cognition","challenging","distinguish","significant","improving","substantial","conversational","alzheimers","specifically","impairment","transcribed","conversation","promising","especially","diagnosis","transcripts","progression","maximizes","alleviate","depression","simultaneously","considerable","neighborhood","precision","estimates","establish","illustrated","deteriorates","convergence","treatment","universally","possesses","eventually","selection","dimensionality","increases","argumentation","programming","abduction","abductive","observation","hypotheses","instantiated","exploration","currently","experiences","behaviour","implementing","explorations","methodology","environment","successfully","architecture","implemented","hazardous","environments","autonomous","multiagent","describes","riemannian","demonstrate","motivates","appealing","definiteness","surprisingly","formulation","substantially","asymptotic","invariably","importance","algorithm","completely","constraints","expectation","alternative","optimization","algorithms","existence","observational","confounders","confounding","fundamental","faithfulness","difficult","protection","estimating","confounded","independencies" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	retrospective
# 	individualized
# 	datapoint
# 	clarifies
# 	directionally
# 	degeneration
# 	complexes
# 	electrocardiogram
# 	initializes
# 	degeneracy
# 	cytometry
# 	integrations
# 	undesired
# 	statistician
# 	judiciously
# 	phylogenetic
# 	accompanies
# 	covariate
# 	connectomics
# 	uncorrupted
# Some words which never appear in Statistics papers:
# 	neutrosophic
# 	contradiction
# 	dialectical
# 	antithesis
# 	conversational
# 	transcribed
# 	conversation
# 	argumentation
# 	abduction
# 	hazardous
# 	multiagent
# 	prospects
# 	inevitable
# 	responders
# 	clinician
# 	determinism
# 	disambiguation
# 	semantical
# 	endogenous
# 	identities

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0543677458766035e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7441666666666666
